# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest, f_classif

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
from ipynb.fs.full.data_loading import load_data_from_csv

# %%
data = load_data_from_csv()

# %%
new_data = data.copy()

# %%
df = pd.DataFrame(columns=["label1", "label2", "label3", "DTaccuracy", "RFaccuracy", "MLPaccuracy", "GSaccuracy"])

# %%
labels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]
for i in range(len(labels)):
    for j in range (len(labels) - i - 1):
        for k in range(len(labels) - i - j - 2):
            print(labels[i], labels[i + j + 1], labels[i + j + k + 2])
            
            new_data_3genre = new_data[(new_data.label == labels[i]) | (new_data.label == labels[i + j + 1]) | (new_data.label == labels[i + j + k + 2])]

            y = new_data_3genre['label']
            X = new_data_3genre.drop(labels=['label', 'filename', 'audio_data', 'audio_sr'],axis=1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=0)

            param_grid_dt = {'splitter': ['best', 'random'], 'max_depth': ['None', 2, 4, 8],
                             'random_state': [0], 'min_samples_leaf': [1, 2, 4, 8]}
            grid_dt = GridSearchCV(DecisionTreeClassifier(), param_grid_dt, refit = True, verbose = 0, cv = 5)
            grid_dt.fit(X_train, y_train)
            y_pred_dt = grid_dt.predict(X_test)
            dt_accuracy = accuracy_score(y_test, y_pred_dt)
            print("DT accuracy:", dt_accuracy)

            param_grid_rf = {'n_estimators': [100, 500, 1000], 'max_depth' : [None, 2, 4, 8],
                            'random_state': [0], 'min_samples_leaf': [1, 2, 4, 8]}
            grid_rf = GridSearchCV(RandomForestClassifier(), param_grid_rf, refit = True, verbose = 0, cv = 5)
            grid_rf.fit(X_train, y_train)
            y_pred_rf = grid_rf.predict(X_test)
            rf_accuracy = accuracy_score(y_test, y_pred_rf)
            print("RF accuracy:", rf_accuracy)

            param_grid_mlp = {'activation': ['identity', 'logistic', 'tanh', 'relu'],
                    'solver': ['lbgfs', 'sgd', 'adam'],
                    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
                    'alpha': [0.0001, 0.05],
                    'learning_rate': ['constant', 'invscaling', 'adaptive']}  
            grid_mlp = GridSearchCV(MLPClassifier(), param_grid_mlp, refit = True, verbose = 0, cv=5)
            grid_mlp.fit(X_train, y_train)
            y_pred_mlp = grid_mlp.predict(X_test) 
            mlp_accuracy = accuracy_score(y_test, y_pred_mlp)
            print("MLP accuracy:", mlp_accuracy) 

            row = {"label1" : labels[i], "label2" : labels[i + j + 1], "label3" : labels[i + j + k + 2], 
                   "DTaccuracy" : dt_accuracy, "RFaccuracy" : rf_accuracy, "MLPaccuracy" : mlp_accuracy}
            df = df.append(row, ignore_index=True)

            print()
# Out:
# blues classical country
# DT accuracy: 0.6958333333333333
# RF accuracy: 0.7916666666666666
# MLP accuracy: 0.49583333333333335
#
# blues classical disco
# DT accuracy: 0.6625
# RF accuracy: 0.875
# MLP accuracy: 0.6541666666666667
#
# blues classical hiphop
# DT accuracy: 0.775
# RF accuracy: 0.8833333333333333
# MLP accuracy: 0.4666666666666667
#
# blues classical jazz
# DT accuracy: 0.75
# RF accuracy: 0.8416666666666667
# MLP accuracy: 0.35
#
# blues classical metal
# DT accuracy: 0.8041666666666667
# RF accuracy: 0.8875
# MLP accuracy: 0.475
#
# blues classical pop
# DT accuracy: 0.85
# RF accuracy: 0.9708333333333333
# MLP accuracy: 0.6333333333333333
#
# blues classical reggae
# DT accuracy: 0.6875
# RF accuracy: 0.8875
# MLP accuracy: 0.6041666666666666
#
# blues classical rock
# DT accuracy: 0.7041666666666667
# RF accuracy: 0.8125
# MLP accuracy: 0.45416666666666666
#
# blues country disco
# DT accuracy: 0.5833333333333334
# RF accuracy: 0.675
# MLP accuracy: 0.4375
#
# blues country hiphop
# DT accuracy: 0.5625
# RF accuracy: 0.7666666666666667
# MLP accuracy: 0.45
#
# blues country jazz
# DT accuracy: 0.6666666666666666
# RF accuracy: 0.825
# MLP accuracy: 0.4083333333333333
#
# blues country metal
# DT accuracy: 0.7333333333333333
# RF accuracy: 0.8
# MLP accuracy: 0.3958333333333333
#
# blues country pop
# DT accuracy: 0.7041666666666667
# RF accuracy: 0.8333333333333334
# MLP accuracy: 0.37083333333333335
#
# blues country reggae
# DT accuracy: 0.6125
# RF accuracy: 0.7458333333333333
# MLP accuracy: 0.375
#
# blues country rock
# DT accuracy: 0.4125
# RF accuracy: 0.6333333333333333
# MLP accuracy: 0.4041666666666667
#
# blues disco hiphop
# DT accuracy: 0.6125
# RF accuracy: 0.7416666666666667
# MLP accuracy: 0.425
#
# blues disco jazz
# DT accuracy: 0.6458333333333334
# RF accuracy: 0.8458333333333333
# MLP accuracy: 0.32083333333333336
#
# blues disco metal
# DT accuracy: 0.7583333333333333
# RF accuracy: 0.8208333333333333
# MLP accuracy: 0.39166666666666666
#
# blues disco pop
# DT accuracy: 0.6458333333333334
# RF accuracy: 0.8458333333333333
# MLP accuracy: 0.4375
#
# blues disco reggae
# DT accuracy: 0.6083333333333333
# RF accuracy: 0.775
# MLP accuracy: 0.3958333333333333
#
# blues disco rock
# DT accuracy: 0.49583333333333335
# RF accuracy: 0.675
# MLP accuracy: 0.44166666666666665
#
# blues hiphop jazz
# DT accuracy: 0.7625
# RF accuracy: 0.8875
# MLP accuracy: 0.5708333333333333
#
# blues hiphop metal
# DT accuracy: 0.7583333333333333
# RF accuracy: 0.8666666666666667
# MLP accuracy: 0.42083333333333334
#
# blues hiphop pop
# DT accuracy: 0.725
# RF accuracy: 0.8833333333333333
# MLP accuracy: 0.45
#
# blues hiphop reggae
# DT accuracy: 0.5208333333333334
# RF accuracy: 0.6583333333333333
# MLP accuracy: 0.4625
#
# blues hiphop rock
# DT accuracy: 0.6708333333333333
# RF accuracy: 0.7875
# MLP accuracy: 0.325
#
# blues jazz metal
# DT accuracy: 0.7833333333333333
# RF accuracy: 0.8708333333333333
# MLP accuracy: 0.43333333333333335
#
# blues jazz pop
# DT accuracy: 0.7833333333333333
# RF accuracy: 0.9041666666666667
# MLP accuracy: 0.6
#
# blues jazz reggae
# DT accuracy: 0.6708333333333333
# RF accuracy: 0.8125
# MLP accuracy: 0.25
#
# blues jazz rock
# DT accuracy: 0.5666666666666667
# RF accuracy: 0.7791666666666667
# MLP accuracy: 0.37083333333333335
#
# blues metal pop
# DT accuracy: 0.8333333333333334
# RF accuracy: 0.8708333333333333
# MLP accuracy: 0.4125
#
# blues metal reggae
# DT accuracy: 0.7041666666666667
# RF accuracy: 0.7833333333333333
# MLP accuracy: 0.3125
#
# blues metal rock
# DT accuracy: 0.6208333333333333
# RF accuracy: 0.6666666666666666
# MLP accuracy: 0.42083333333333334
#
# blues pop reggae
# DT accuracy: 0.6333333333333333
# RF accuracy: 0.7791666666666667
# MLP accuracy: 0.48333333333333334
#
# blues pop rock
# DT accuracy: 0.6791666666666667
# RF accuracy: 0.8
# MLP accuracy: 0.4125
#
# blues reggae rock
# DT accuracy: 0.5541666666666667
# RF accuracy: 0.7291666666666666
# MLP accuracy: 0.35
#
# classical country disco
# DT accuracy: 0.7333333333333333
# RF accuracy: 0.7708333333333334
# MLP accuracy: 0.4708333333333333
#
# classical country hiphop
# DT accuracy: 0.75
# RF accuracy: 0.8125
# MLP accuracy: 0.7
#
# classical country jazz
# DT accuracy: 0.7208333333333333
# RF accuracy: 0.8
# MLP accuracy: 0.525
#
# classical country metal
# DT accuracy: 0.8416666666666667
# RF accuracy: 0.9041666666666667
# MLP accuracy: 0.3416666666666667
#
# classical country pop
# DT accuracy: 0.7791666666666667
# RF accuracy: 0.8916666666666667
# MLP accuracy: 0.6166666666666667
#
# classical country reggae
# DT accuracy: 0.6375
# RF accuracy: 0.8208333333333333
# MLP accuracy: 0.5833333333333334
#
# classical country rock
# DT accuracy: 0.5333333333333333
# RF accuracy: 0.725
# MLP accuracy: 0.42083333333333334
#
# classical disco hiphop
# DT accuracy: 0.675
# RF accuracy: 0.8
# MLP accuracy: 0.5375
#
# classical disco jazz
# DT accuracy: 0.8083333333333333
# RF accuracy: 0.8291666666666667
# MLP accuracy: 0.3541666666666667
#
# classical disco metal
# DT accuracy: 0.7541666666666667
# RF accuracy: 0.8958333333333334
# MLP accuracy: 0.475
#
# classical disco pop
# DT accuracy: 0.7791666666666667
# RF accuracy: 0.8958333333333334
# MLP accuracy: 0.5208333333333334
#
# classical disco reggae
# DT accuracy: 0.6916666666666667
# RF accuracy: 0.85
# MLP accuracy: 0.38333333333333336
#
# classical disco rock
# DT accuracy: 0.625
# RF accuracy: 0.7375
# MLP accuracy: 0.5708333333333333
#
# classical hiphop jazz
# DT accuracy: 0.8458333333333333
# RF accuracy: 0.8583333333333333
# MLP accuracy: 0.6583333333333333
#
# classical hiphop metal
# DT accuracy: 0.775
# RF accuracy: 0.9208333333333333
# MLP accuracy: 0.35
#
# classical hiphop pop
# DT accuracy: 0.775
# RF accuracy: 0.9041666666666667
# MLP accuracy: 0.475
#
# classical hiphop reggae
# DT accuracy: 0.6708333333333333
# RF accuracy: 0.7875
# MLP accuracy: 0.625
#
# classical hiphop rock
# DT accuracy: 0.6666666666666666
# RF accuracy: 0.8625
# MLP accuracy: 0.5708333333333333
#
# classical jazz metal
# DT accuracy: 0.8
# RF accuracy: 0.8541666666666666
# MLP accuracy: 0.5541666666666667
#
# classical jazz pop
# DT accuracy: 0.6375
# RF accuracy: 0.8458333333333333
# MLP accuracy: 0.6833333333333333
#
# classical jazz reggae
# DT accuracy: 0.6541666666666667
# RF accuracy: 0.8
# MLP accuracy: 0.5625
#
# classical jazz rock
# DT accuracy: 0.6458333333333334
# RF accuracy: 0.825
# MLP accuracy: 0.6333333333333333
#
# classical metal pop
# DT accuracy: 0.9041666666666667
# RF accuracy: 0.9666666666666667
# MLP accuracy: 0.3875
#
# classical metal reggae
# DT accuracy: 0.8583333333333333
# RF accuracy: 0.925
# MLP accuracy: 0.4583333333333333
#
# classical metal rock
# DT accuracy: 0.725
# RF accuracy: 0.7791666666666667
# MLP accuracy: 0.45416666666666666
#
# classical pop reggae
# DT accuracy: 0.7708333333333334
# RF accuracy: 0.8666666666666667
# MLP accuracy: 0.5625
#
# classical pop rock
# DT accuracy: 0.8375
# RF accuracy: 0.8916666666666667
# MLP accuracy: 0.6
#
# classical reggae rock
# DT accuracy: 0.7333333333333333
# RF accuracy: 0.825
# MLP accuracy: 0.4375
#
# country disco hiphop
# DT accuracy: 0.5041666666666667
# RF accuracy: 0.7208333333333333
# MLP accuracy: 0.525
#
# country disco jazz
# DT accuracy: 0.6666666666666666
# RF accuracy: 0.75
# MLP accuracy: 0.4708333333333333
#
# country disco metal
# DT accuracy: 0.5958333333333333
# RF accuracy: 0.75
# MLP accuracy: 0.4791666666666667
#
# country disco pop
# DT accuracy: 0.7291666666666666
# RF accuracy: 0.8291666666666667
# MLP accuracy: 0.44583333333333336
#
# country disco reggae
# DT accuracy: 0.5916666666666667
# RF accuracy: 0.7458333333333333
# MLP accuracy: 0.3625
#
# country disco rock
# DT accuracy: 0.45
# RF accuracy: 0.5416666666666666
# MLP accuracy: 0.43333333333333335
#
# country hiphop jazz
# DT accuracy: 0.7375
# RF accuracy: 0.8541666666666666
# MLP accuracy: 0.4583333333333333
#
# country hiphop metal
# DT accuracy: 0.8416666666666667
# RF accuracy: 0.8791666666666667
# MLP accuracy: 0.5416666666666666
#
# country hiphop pop
# DT accuracy: 0.6791666666666667
# RF accuracy: 0.825
# MLP accuracy: 0.5083333333333333
#
# country hiphop reggae
# DT accuracy: 0.6291666666666667
# RF accuracy: 0.7041666666666667
# MLP accuracy: 0.48333333333333334
#
# country hiphop rock
# DT accuracy: 0.6125
# RF accuracy: 0.7541666666666667
# MLP accuracy: 0.5
#
# country jazz metal
# DT accuracy: 0.7
# RF accuracy: 0.8916666666666667
# MLP accuracy: 0.5083333333333333
#
# country jazz pop
# DT accuracy: 0.7166666666666667
# RF accuracy: 0.875
# MLP accuracy: 0.5541666666666667
#
# country jazz reggae
# DT accuracy: 0.5583333333333333
# RF accuracy: 0.8208333333333333
# MLP accuracy: 0.2916666666666667
#
# country jazz rock
# DT accuracy: 0.5583333333333333
# RF accuracy: 0.75
# MLP accuracy: 0.38333333333333336
#
# country metal pop
# DT accuracy: 0.7625
# RF accuracy: 0.8666666666666667
# MLP accuracy: 0.5083333333333333
#
# country metal reggae
# DT accuracy: 0.6291666666666667
# RF accuracy: 0.8
# MLP accuracy: 0.48333333333333334
#
# country metal rock
# DT accuracy: 0.5916666666666667
# RF accuracy: 0.65
# MLP accuracy: 0.3958333333333333
#
# country pop reggae
# DT accuracy: 0.6416666666666667
# RF accuracy: 0.775
# MLP accuracy: 0.3625
#
# country pop rock
# DT accuracy: 0.625
# RF accuracy: 0.7958333333333333
# MLP accuracy: 0.5166666666666667
#
# country reggae rock
# DT accuracy: 0.6
# RF accuracy: 0.7166666666666667
# MLP accuracy: 0.32083333333333336
#
# disco hiphop jazz
# DT accuracy: 0.7458333333333333
# RF accuracy: 0.7916666666666666
# MLP accuracy: 0.48333333333333334
#
# disco hiphop metal
# DT accuracy: 0.5291666666666667
# RF accuracy: 0.7541666666666667
# MLP accuracy: 0.3541666666666667
#
# disco hiphop pop
# DT accuracy: 0.5958333333333333
# RF accuracy: 0.7541666666666667
# MLP accuracy: 0.37083333333333335
#
# disco hiphop reggae
# DT accuracy: 0.6083333333333333
# RF accuracy: 0.6416666666666667
# MLP accuracy: 0.375
#
# disco hiphop rock
# DT accuracy: 0.5541666666666667
# RF accuracy: 0.65
# MLP accuracy: 0.4125
#
# disco jazz metal
# DT accuracy: 0.8416666666666667
# RF accuracy: 0.9208333333333333
# MLP accuracy: 0.4
#
# disco jazz pop
# DT accuracy: 0.6875
# RF accuracy: 0.8833333333333333
# MLP accuracy: 0.5291666666666667
#
# disco jazz reggae
# DT accuracy: 0.6916666666666667
# RF accuracy: 0.8375
# MLP accuracy: 0.37083333333333335
#
# disco jazz rock
# DT accuracy: 0.625
# RF accuracy: 0.7375
# MLP accuracy: 0.4791666666666667
#
# disco metal pop
# DT accuracy: 0.7541666666666667
# RF accuracy: 0.8
# MLP accuracy: 0.3416666666666667
#
# disco metal reggae
# DT accuracy: 0.6916666666666667
# RF accuracy: 0.7666666666666667
# MLP accuracy: 0.45
#
# disco metal rock
# DT accuracy: 0.49166666666666664
# RF accuracy: 0.5833333333333334
# MLP accuracy: 0.375
#
# disco pop reggae
# DT accuracy: 0.7
# RF accuracy: 0.7666666666666667
# MLP accuracy: 0.32083333333333336
#
# disco pop rock
# DT accuracy: 0.6125
# RF accuracy: 0.675
# MLP accuracy: 0.325
#
# disco reggae rock
# DT accuracy: 0.5583333333333333
# RF accuracy: 0.6458333333333334
# MLP accuracy: 0.3375
#
# hiphop jazz metal
# DT accuracy: 0.8625
# RF accuracy: 0.9083333333333333
# MLP accuracy: 0.44583333333333336
#
# hiphop jazz pop
# DT accuracy: 0.75
# RF accuracy: 0.8791666666666667
# MLP accuracy: 0.4875
#
# hiphop jazz reggae
# DT accuracy: 0.6208333333333333
# RF accuracy: 0.7791666666666667
# MLP accuracy: 0.4666666666666667
#
# hiphop jazz rock
# DT accuracy: 0.625
# RF accuracy: 0.8166666666666667
# MLP accuracy: 0.5
#
# hiphop metal pop
# DT accuracy: 0.6791666666666667
# RF accuracy: 0.8208333333333333
# MLP accuracy: 0.32916666666666666
#
# hiphop metal reggae
# DT accuracy: 0.6958333333333333
# RF accuracy: 0.7125
# MLP accuracy: 0.38333333333333336
#
# hiphop metal rock
# DT accuracy: 0.575
# RF accuracy: 0.7
# MLP accuracy: 0.4125
#
# hiphop pop reggae
# DT accuracy: 0.6666666666666666
# RF accuracy: 0.75
# MLP accuracy: 0.3458333333333333
#
# hiphop pop rock
# DT accuracy: 0.6583333333333333
# RF accuracy: 0.8208333333333333
# MLP accuracy: 0.475
#
# hiphop reggae rock
# DT accuracy: 0.6291666666666667
# RF accuracy: 0.6708333333333333
# MLP accuracy: 0.4
#
# jazz metal pop
# DT accuracy: 0.825
# RF accuracy: 0.9458333333333333
# MLP accuracy: 0.6291666666666667
#
# jazz metal reggae
# DT accuracy: 0.8125
# RF accuracy: 0.9125
# MLP accuracy: 0.4875
#
# jazz metal rock
# DT accuracy: 0.6291666666666667
# RF accuracy: 0.7833333333333333
# MLP accuracy: 0.5333333333333333
#
# jazz pop reggae
# DT accuracy: 0.5791666666666667
# RF accuracy: 0.8375
# MLP accuracy: 0.5125
#
# jazz pop rock
# DT accuracy: 0.5958333333333333
# RF accuracy: 0.8083333333333333
# MLP accuracy: 0.575
#
# jazz reggae rock
# DT accuracy: 0.7208333333333333
# RF accuracy: 0.7833333333333333
# MLP accuracy: 0.43333333333333335
#
# metal pop reggae
# DT accuracy: 0.775
# RF accuracy: 0.8791666666666667
# MLP accuracy: 0.44166666666666665
#
# metal pop rock
# DT accuracy: 0.7583333333333333
# RF accuracy: 0.8166666666666667
# MLP accuracy: 0.5833333333333334
#
# metal reggae rock
# DT accuracy: 0.625
# RF accuracy: 0.7833333333333333
# MLP accuracy: 0.4083333333333333
#
# pop reggae rock
# DT accuracy: 0.5666666666666667
# RF accuracy: 0.8
# MLP accuracy: 0.45416666666666666

# %%
df.head()
# Out:
#   label1     label2   label3  DTaccuracy  RFaccuracy  MLPaccuracy  GSaccuracy
# 0  blues  classical  country    0.695833    0.820833     0.341667    0.358333
# 1  blues  classical    disco    0.729167    0.850000     0.341667    0.479167
# 2  blues  classical   hiphop    0.854167    0.887500     0.341667    0.637500
# 3  blues  classical     jazz    0.612500    0.808333     0.341667    0.566667
# 4  blues  classical    metal    0.845833    0.895833     0.341667    0.591667

# %%
df.to_csv('classification_data_3_genre.csv', index=False)
