# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest, f_classif

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
from ipynb.fs.full.data_loading import get_usable_data

# %%
data = get_usable_data()

# %%
new_data = data.copy()

# %%
df = pd.DataFrame(columns=["label1", "label2", "label3", "DTaccuracy", "RFaccuracy", "MLPaccuracy", "GSaccuracy"])

# %%
labels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]
for i in range(len(labels)):
    for j in range (len(labels) - i - 1):
        for k in range(len(labels) - i - j - 2):
            print(labels[i], labels[i + j + 1], labels[i + j + k + 2])
            
            new_data_3genre = new_data[(new_data.label == labels[i]) | (new_data.label == labels[i + j + 1]) | (new_data.label == labels[i + j + k + 2])]

            y = new_data_3genre['label']
            X = new_data_3genre.drop(labels=['label', 'filename', 'audio_data', 'audio_sr'],axis=1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

            dt = DecisionTreeClassifier()
            dt = dt.fit(X_train, y_train)
            y_pred_dt = dt.predict(X_test)
            dtaccuracy = accuracy_score(y_test, y_pred_dt)
            print("DT accuracy:", dtaccuracy)

            rf = RandomForestClassifier()
            rf = rf.fit(X_train, y_train)
            y_pred_rf = dt.predict(X_test)
            rfaccuracy = accuracy_score(y_test, y_pred_rf)
            print("RF accuracy:", rfaccuracy)

            mlp = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
            mlp.fit(X_train, y_train)
            y_pred_mlp = mlp.predict(X_test)
            mlpaccuracy = accuracy_score(y_test, y_pred_mlp)
            print("MLP accuracy:", mlpaccuracy)


            param_grid = {'activation': ['identity', 'logistic', 'tanh', 'relu'],
                    'solver': ['lbgfs', 'sgd', 'adam'],
                    'learning_rate': ['constant', 'invscaling', 'adaptive']}  
            grid = GridSearchCV(MLPClassifier(), param_grid, refit = True, verbose = 0, cv=5)
            grid.fit(X_train, y_train)
            y_pred_gs = grid.predict(X_test) 
            gsaccuracy = accuracy_score(y_test, y_pred_gs)
            print("Grid accuracy:", gsaccuracy) 
            #print("Grid classification:", classification_report(y_test, grid_predictions)) 

            row = {"label1" : labels[i], "label2" : labels[i + j + 1], "label3" : labels[i + j + k + 2], 
                   "DTaccuracy" : dtaccuracy, "RFaccuracy" : rfaccuracy, "MLPaccuracy" : mlpaccuracy, "GSaccuracy" : gsaccuracy}
            df = df.append(row, ignore_index=True)

            print()
# Out:
# blues classical country
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.29292929292929293
#
# blues classical disco
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.35353535353535354
#
# blues classical hiphop
# DT accuracy: 0.8383838383838383
# RF accuracy: 0.8383838383838383
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.47474747474747475
#
# blues classical jazz
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.42424242424242425
#
# blues classical metal
# DT accuracy: 0.8585858585858586
# RF accuracy: 0.8585858585858586
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# blues classical pop
# DT accuracy: 0.9191919191919192
# RF accuracy: 0.9191919191919192
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.6565656565656566
#
# blues classical reggae
# DT accuracy: 0.898989898989899
# RF accuracy: 0.898989898989899
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.42424242424242425
#
# blues classical rock
# DT accuracy: 0.7777777777777778
# RF accuracy: 0.7777777777777778
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.43434343434343436
#
# blues country disco
# DT accuracy: 0.6868686868686869
# RF accuracy: 0.6868686868686869
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# blues country hiphop
# DT accuracy: 0.7474747474747475
# RF accuracy: 0.7474747474747475
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3838383838383838
#
# blues country jazz
# DT accuracy: 0.6868686868686869
# RF accuracy: 0.6868686868686869
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.2828282828282828
#
# blues country metal
# DT accuracy: 0.7373737373737373
# RF accuracy: 0.7373737373737373
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.26262626262626265
#
# blues country pop
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5454545454545454
#
# blues country reggae
# DT accuracy: 0.6767676767676768
# RF accuracy: 0.6767676767676768
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.29292929292929293
#
# blues country rock
# DT accuracy: 0.6262626262626263
# RF accuracy: 0.6262626262626263
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3333333333333333
#
# blues disco hiphop
# DT accuracy: 0.6161616161616161
# RF accuracy: 0.6161616161616161
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.29292929292929293
#
# blues disco jazz
# DT accuracy: 0.6060606060606061
# RF accuracy: 0.6060606060606061
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.47474747474747475
#
# blues disco metal
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.42424242424242425
#
# blues disco pop
# DT accuracy: 0.7070707070707071
# RF accuracy: 0.7070707070707071
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3333333333333333
#
# blues disco reggae
# DT accuracy: 0.6363636363636364
# RF accuracy: 0.6363636363636364
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# blues disco rock
# DT accuracy: 0.6363636363636364
# RF accuracy: 0.6363636363636364
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# blues hiphop jazz
# DT accuracy: 0.8686868686868687
# RF accuracy: 0.8686868686868687
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5050505050505051
#
# blues hiphop metal
# DT accuracy: 0.7676767676767676
# RF accuracy: 0.7676767676767676
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# blues hiphop pop
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.41414141414141414
#
# blues hiphop reggae
# DT accuracy: 0.7676767676767676
# RF accuracy: 0.7676767676767676
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3838383838383838
#
# blues hiphop rock
# DT accuracy: 0.7373737373737373
# RF accuracy: 0.7373737373737373
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# blues jazz metal
# DT accuracy: 0.7474747474747475
# RF accuracy: 0.7474747474747475
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.29292929292929293
#
# blues jazz pop
# DT accuracy: 0.8282828282828283
# RF accuracy: 0.8282828282828283
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5353535353535354
#
# blues jazz reggae
# DT accuracy: 0.7171717171717171
# RF accuracy: 0.7171717171717171
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.3939393939393939
#
# blues jazz rock
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.2828282828282828
#
# blues metal pop
# DT accuracy: 0.8080808080808081
# RF accuracy: 0.8080808080808081
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.29292929292929293
#
# blues metal reggae
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3838383838383838
#
# blues metal rock
# DT accuracy: 0.6666666666666666
# RF accuracy: 0.6666666666666666
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.35353535353535354
#
# blues pop reggae
# DT accuracy: 0.7373737373737373
# RF accuracy: 0.7373737373737373
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5050505050505051
#
# blues pop rock
# DT accuracy: 0.696969696969697
# RF accuracy: 0.696969696969697
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3838383838383838
#
# blues reggae rock
# DT accuracy: 0.6565656565656566
# RF accuracy: 0.6565656565656566
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.29292929292929293
#
# classical country disco
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# classical country hiphop
# DT accuracy: 0.8080808080808081
# RF accuracy: 0.8080808080808081
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.48484848484848486
#
# classical country jazz
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.2828282828282828
#
# classical country metal
# DT accuracy: 0.9090909090909091
# RF accuracy: 0.9090909090909091
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.6464646464646465
#
# classical country pop
# DT accuracy: 0.8383838383838383
# RF accuracy: 0.8383838383838383
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.43434343434343436
#
# classical country reggae
# DT accuracy: 0.7373737373737373
# RF accuracy: 0.7373737373737373
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.24242424242424243
#
# classical country rock
# DT accuracy: 0.7474747474747475
# RF accuracy: 0.7474747474747475
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3333333333333333
#
# classical disco hiphop
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5151515151515151
#
# classical disco jazz
# DT accuracy: 0.797979797979798
# RF accuracy: 0.797979797979798
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.30303030303030304
#
# classical disco metal
# DT accuracy: 0.8686868686868687
# RF accuracy: 0.8686868686868687
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3939393939393939
#
# classical disco pop
# DT accuracy: 0.8787878787878788
# RF accuracy: 0.8787878787878788
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.46464646464646464
#
# classical disco reggae
# DT accuracy: 0.797979797979798
# RF accuracy: 0.797979797979798
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5353535353535354
#
# classical disco rock
# DT accuracy: 0.696969696969697
# RF accuracy: 0.696969696969697
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.45454545454545453
#
# classical hiphop jazz
# DT accuracy: 0.7777777777777778
# RF accuracy: 0.7777777777777778
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.7373737373737373
#
# classical hiphop metal
# DT accuracy: 0.8282828282828283
# RF accuracy: 0.8282828282828283
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5353535353535354
#
# classical hiphop pop
# DT accuracy: 0.8181818181818182
# RF accuracy: 0.8181818181818182
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.4444444444444444
#
# classical hiphop reggae
# DT accuracy: 0.8080808080808081
# RF accuracy: 0.8080808080808081
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.48484848484848486
#
# classical hiphop rock
# DT accuracy: 0.8181818181818182
# RF accuracy: 0.8181818181818182
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.6161616161616161
#
# classical jazz metal
# DT accuracy: 0.8383838383838383
# RF accuracy: 0.8383838383838383
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.6464646464646465
#
# classical jazz pop
# DT accuracy: 0.797979797979798
# RF accuracy: 0.797979797979798
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5555555555555556
#
# classical jazz reggae
# DT accuracy: 0.8282828282828283
# RF accuracy: 0.8282828282828283
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.46464646464646464
#
# classical jazz rock
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.40404040404040403
#
# classical metal pop
# DT accuracy: 0.9090909090909091
# RF accuracy: 0.9090909090909091
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5353535353535354
#
# classical metal reggae
# DT accuracy: 0.898989898989899
# RF accuracy: 0.898989898989899
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5151515151515151
#
# classical metal rock
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3838383838383838
#
# classical pop reggae
# DT accuracy: 0.8686868686868687
# RF accuracy: 0.8686868686868687
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.48484848484848486
#
# classical pop rock
# DT accuracy: 0.8888888888888888
# RF accuracy: 0.8888888888888888
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.6060606060606061
#
# classical reggae rock
# DT accuracy: 0.7777777777777778
# RF accuracy: 0.7777777777777778
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.5050505050505051
#
# country disco hiphop
# DT accuracy: 0.6363636363636364
# RF accuracy: 0.6363636363636364
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.48484848484848486
#
# country disco jazz
# DT accuracy: 0.7777777777777778
# RF accuracy: 0.7777777777777778
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.3333333333333333
#
# country disco metal
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.41414141414141414
#
# country disco pop
# DT accuracy: 0.7676767676767676
# RF accuracy: 0.7676767676767676
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# country disco reggae
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# country disco rock
# DT accuracy: 0.5757575757575758
# RF accuracy: 0.5757575757575758
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.37373737373737376
#
# country hiphop jazz
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.6060606060606061
#
# country hiphop metal
# DT accuracy: 0.8888888888888888
# RF accuracy: 0.8888888888888888
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# country hiphop pop
# DT accuracy: 0.8282828282828283
# RF accuracy: 0.8282828282828283
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# country hiphop reggae
# DT accuracy: 0.7474747474747475
# RF accuracy: 0.7474747474747475
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.43434343434343436
#
# country hiphop rock
# DT accuracy: 0.7474747474747475
# RF accuracy: 0.7474747474747475
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.48484848484848486
#
# country jazz metal
# DT accuracy: 0.8181818181818182
# RF accuracy: 0.8181818181818182
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5252525252525253
#
# country jazz pop
# DT accuracy: 0.7676767676767676
# RF accuracy: 0.7676767676767676
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.47474747474747475
#
# country jazz reggae
# DT accuracy: 0.7171717171717171
# RF accuracy: 0.7171717171717171
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.3939393939393939
#
# country jazz rock
# DT accuracy: 0.5757575757575758
# RF accuracy: 0.5757575757575758
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.4444444444444444
#
# country metal pop
# DT accuracy: 0.8282828282828283
# RF accuracy: 0.8282828282828283
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.43434343434343436
#
# country metal reggae
# DT accuracy: 0.7474747474747475
# RF accuracy: 0.7474747474747475
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3333333333333333
#
# country metal rock
# DT accuracy: 0.6565656565656566
# RF accuracy: 0.6565656565656566
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.47474747474747475
#
# country pop reggae
# DT accuracy: 0.797979797979798
# RF accuracy: 0.797979797979798
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.37373737373737376
#
# country pop rock
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# country reggae rock
# DT accuracy: 0.6565656565656566
# RF accuracy: 0.6565656565656566
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3333333333333333
#
# disco hiphop jazz
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5151515151515151
#
# disco hiphop metal
# DT accuracy: 0.696969696969697
# RF accuracy: 0.696969696969697
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.31313131313131315
#
# disco hiphop pop
# DT accuracy: 0.6464646464646465
# RF accuracy: 0.6464646464646465
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.37373737373737376
#
# disco hiphop reggae
# DT accuracy: 0.5454545454545454
# RF accuracy: 0.5454545454545454
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# disco hiphop rock
# DT accuracy: 0.4444444444444444
# RF accuracy: 0.4444444444444444
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.30303030303030304
#
# disco jazz metal
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.43434343434343436
#
# disco jazz pop
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5454545454545454
#
# disco jazz reggae
# DT accuracy: 0.7474747474747475
# RF accuracy: 0.7474747474747475
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.4444444444444444
#
# disco jazz rock
# DT accuracy: 0.6464646464646465
# RF accuracy: 0.6464646464646465
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.494949494949495
#
# disco metal pop
# DT accuracy: 0.7777777777777778
# RF accuracy: 0.7777777777777778
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.29292929292929293
#
# disco metal reggae
# DT accuracy: 0.7373737373737373
# RF accuracy: 0.7373737373737373
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3333333333333333
#
# disco metal rock
# DT accuracy: 0.6868686868686869
# RF accuracy: 0.6868686868686869
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.2828282828282828
#
# disco pop reggae
# DT accuracy: 0.7575757575757576
# RF accuracy: 0.7575757575757576
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3838383838383838
#
# disco pop rock
# DT accuracy: 0.7070707070707071
# RF accuracy: 0.7070707070707071
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# disco reggae rock
# DT accuracy: 0.6262626262626263
# RF accuracy: 0.6262626262626263
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.29292929292929293
#
# hiphop jazz metal
# DT accuracy: 0.9191919191919192
# RF accuracy: 0.9191919191919192
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5757575757575758
#
# hiphop jazz pop
# DT accuracy: 0.8080808080808081
# RF accuracy: 0.8080808080808081
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.47474747474747475
#
# hiphop jazz reggae
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.46464646464646464
#
# hiphop jazz rock
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5555555555555556
#
# hiphop metal pop
# DT accuracy: 0.7575757575757576
# RF accuracy: 0.7575757575757576
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.30303030303030304
#
# hiphop metal reggae
# DT accuracy: 0.7171717171717171
# RF accuracy: 0.7171717171717171
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.41414141414141414
#
# hiphop metal rock
# DT accuracy: 0.7171717171717171
# RF accuracy: 0.7171717171717171
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# hiphop pop reggae
# DT accuracy: 0.7070707070707071
# RF accuracy: 0.7070707070707071
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# hiphop pop rock
# DT accuracy: 0.7575757575757576
# RF accuracy: 0.7575757575757576
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.3434343434343434
#
# hiphop reggae rock
# DT accuracy: 0.6464646464646465
# RF accuracy: 0.6464646464646465
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.41414141414141414
#
# jazz metal pop
# DT accuracy: 0.9191919191919192
# RF accuracy: 0.9191919191919192
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.5353535353535354
#
# jazz metal reggae
# DT accuracy: 0.8888888888888888
# RF accuracy: 0.8888888888888888
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.30303030303030304
#
# jazz metal rock
# DT accuracy: 0.8080808080808081
# RF accuracy: 0.8080808080808081
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.41414141414141414
#
# jazz pop reggae
# DT accuracy: 0.8787878787878788
# RF accuracy: 0.8787878787878788
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.40404040404040403
#
# jazz pop rock
# DT accuracy: 0.8181818181818182
# RF accuracy: 0.8181818181818182
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.2222222222222222
#
# jazz reggae rock
# DT accuracy: 0.7676767676767676
# RF accuracy: 0.7676767676767676
# MLP accuracy: 0.37373737373737376
# Grid accuracy: 0.36363636363636365
#
# metal pop reggae
# DT accuracy: 0.797979797979798
# RF accuracy: 0.797979797979798
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.35353535353535354
#
# metal pop rock
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.37373737373737376
#
# metal reggae rock
# DT accuracy: 0.7272727272727273
# RF accuracy: 0.7272727272727273
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.36363636363636365
#
# pop reggae rock
# DT accuracy: 0.6666666666666666
# RF accuracy: 0.6666666666666666
# MLP accuracy: 0.36363636363636365
# Grid accuracy: 0.42424242424242425

# %%
df.head()
# Out:
#   label1     label2   label3  DTaccuracy  RFaccuracy  MLPaccuracy  GSaccuracy
# 0  blues  classical  country    0.727273    0.727273     0.363636    0.292929
# 1  blues  classical    disco    0.848485    0.848485     0.363636    0.353535
# 2  blues  classical   hiphop    0.838384    0.838384     0.363636    0.474747
# 3  blues  classical     jazz    0.787879    0.787879     0.373737    0.424242
# 4  blues  classical    metal    0.858586    0.858586     0.363636    0.343434

# %%
df.to_csv('classification_data_3_genre.csv', index=False)
