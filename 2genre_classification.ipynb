# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest, f_classif

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
from ipynb.fs.full.data_loading import get_usable_data

# %%
data = get_usable_data()

# %%
new_data = data.copy()

# %%
df = pd.DataFrame(columns=["label1", "label2", "DTaccuracy", "RFaccuracy", "MLPaccuracy", "GSaccuracy"])

# %%
labels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]
for i in range(len(labels)):
    for j in range(len(labels) - i - 1):
                
        print(labels[i], labels[i + j + 1])
        
        new_data_2genre = new_data[(new_data.label == labels[i]) | (new_data.label == labels[i + j + 1])]

        y = new_data_2genre['label']
        X = new_data_2genre.drop(labels=['label', 'filename', 'audio_data', 'audio_sr'],axis=1)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)
        
        dt = DecisionTreeClassifier()
        dt = dt.fit(X_train, y_train)
        y_pred_dt = dt.predict(X_test)
        dtaccuracy = accuracy_score(y_test, y_pred_dt)
        print("DT accuracy:", dtaccuracy)
                
        rf = RandomForestClassifier()
        rf = rf.fit(X_train, y_train)
        y_pred_rf = dt.predict(X_test)
        rfaccuracy = accuracy_score(y_test, y_pred_rf)
        print("RF accuracy:", rfaccuracy)
        
        mlp = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
        mlp.fit(X_train, y_train)
        y_pred_mlp = mlp.predict(X_test)
        mlpaccuracy = accuracy_score(y_test, y_pred_mlp)
        print("MLP accuracy:", mlpaccuracy)
        
        
        param_grid = {'activation': ['identity', 'logistic', 'tanh', 'relu'],
                'solver': ['lbgfs', 'sgd', 'adam'],
                'learning_rate': ['constant', 'invscaling', 'adaptive']}  
        grid = GridSearchCV(MLPClassifier(), param_grid, refit = True, verbose = 0, cv=5)
        grid.fit(X_train, y_train)
        y_pred_gs = grid.predict(X_test) 
        gsaccuracy = accuracy_score(y_test, y_pred_gs)
        print("Grid accuracy:", gsaccuracy) 
                
        row = {"label1" : labels[i], "label2" : labels[i + j + 1], "DTaccuracy" : dtaccuracy, "RFaccuracy" : rfaccuracy, "MLPaccuracy" : mlpaccuracy, "GSaccuracy" : gsaccuracy}
        df = df.append(row, ignore_index=True)
        
        print()
# Out:
# blues classical
# DT accuracy: 0.8333333333333334
# RF accuracy: 0.8333333333333334
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5757575757575758
#
# blues country
# DT accuracy: 0.7727272727272727
# RF accuracy: 0.7727272727272727
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5303030303030303
#
# blues disco
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5606060606060606
#
# blues hiphop
# DT accuracy: 0.8333333333333334
# RF accuracy: 0.8333333333333334
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6060606060606061
#
# blues jazz
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.5
# Grid accuracy: 0.5606060606060606
#
# blues metal
# DT accuracy: 0.8333333333333334
# RF accuracy: 0.8333333333333334
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5151515151515151
#
# blues pop
# DT accuracy: 0.9848484848484849
# RF accuracy: 0.9848484848484849
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6212121212121212
#
# blues reggae
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.7272727272727273
#
# blues rock
# DT accuracy: 0.6818181818181818
# RF accuracy: 0.6818181818181818
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5757575757575758
#
# classical country
# DT accuracy: 0.9545454545454546
# RF accuracy: 0.9545454545454546
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.8333333333333334
#
# classical disco
# DT accuracy: 1.0
# RF accuracy: 1.0
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5151515151515151
#
# classical hiphop
# DT accuracy: 0.9848484848484849
# RF accuracy: 0.9848484848484849
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.696969696969697
#
# classical jazz
# DT accuracy: 0.8787878787878788
# RF accuracy: 0.8787878787878788
# MLP accuracy: 0.5
# Grid accuracy: 0.7727272727272727
#
# classical metal
# DT accuracy: 0.9393939393939394
# RF accuracy: 0.9393939393939394
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5454545454545454
#
# classical pop
# DT accuracy: 0.9545454545454546
# RF accuracy: 0.9545454545454546
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.803030303030303
#
# classical reggae
# DT accuracy: 0.9696969696969697
# RF accuracy: 0.9696969696969697
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5606060606060606
#
# classical rock
# DT accuracy: 1.0
# RF accuracy: 1.0
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.8181818181818182
#
# country disco
# DT accuracy: 0.8636363636363636
# RF accuracy: 0.8636363636363636
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6818181818181818
#
# country hiphop
# DT accuracy: 0.9090909090909091
# RF accuracy: 0.9090909090909091
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6060606060606061
#
# country jazz
# DT accuracy: 0.7727272727272727
# RF accuracy: 0.7727272727272727
# MLP accuracy: 0.5
# Grid accuracy: 0.48484848484848486
#
# country metal
# DT accuracy: 0.9696969696969697
# RF accuracy: 0.9696969696969697
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.7727272727272727
#
# country pop
# DT accuracy: 0.8939393939393939
# RF accuracy: 0.8939393939393939
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.696969696969697
#
# country reggae
# DT accuracy: 0.7575757575757576
# RF accuracy: 0.7575757575757576
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6515151515151515
#
# country rock
# DT accuracy: 0.6212121212121212
# RF accuracy: 0.6212121212121212
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5606060606060606
#
# disco hiphop
# DT accuracy: 0.5606060606060606
# RF accuracy: 0.5606060606060606
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5909090909090909
#
# disco jazz
# DT accuracy: 0.9393939393939394
# RF accuracy: 0.9393939393939394
# MLP accuracy: 0.5
# Grid accuracy: 0.7424242424242424
#
# disco metal
# DT accuracy: 0.8787878787878788
# RF accuracy: 0.8787878787878788
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5151515151515151
#
# disco pop
# DT accuracy: 0.8181818181818182
# RF accuracy: 0.8181818181818182
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.45454545454545453
#
# disco reggae
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5757575757575758
#
# disco rock
# DT accuracy: 0.6212121212121212
# RF accuracy: 0.6212121212121212
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5454545454545454
#
# hiphop jazz
# DT accuracy: 0.8939393939393939
# RF accuracy: 0.8939393939393939
# MLP accuracy: 0.5
# Grid accuracy: 0.696969696969697
#
# hiphop metal
# DT accuracy: 0.9545454545454546
# RF accuracy: 0.9545454545454546
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.8333333333333334
#
# hiphop pop
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.4393939393939394
#
# hiphop reggae
# DT accuracy: 0.6515151515151515
# RF accuracy: 0.6515151515151515
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6212121212121212
#
# hiphop rock
# DT accuracy: 0.8484848484848485
# RF accuracy: 0.8484848484848485
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5151515151515151
#
# jazz metal
# DT accuracy: 0.9696969696969697
# RF accuracy: 0.9696969696969697
# MLP accuracy: 0.5
# Grid accuracy: 0.7121212121212122
#
# jazz pop
# DT accuracy: 0.8939393939393939
# RF accuracy: 0.8939393939393939
# MLP accuracy: 0.5
# Grid accuracy: 0.803030303030303
#
# jazz reggae
# DT accuracy: 0.8333333333333334
# RF accuracy: 0.8333333333333334
# MLP accuracy: 0.5
# Grid accuracy: 0.42424242424242425
#
# jazz rock
# DT accuracy: 0.8636363636363636
# RF accuracy: 0.8636363636363636
# MLP accuracy: 0.5
# Grid accuracy: 0.5151515151515151
#
# metal pop
# DT accuracy: 0.9696969696969697
# RF accuracy: 0.9696969696969697
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5151515151515151
#
# metal reggae
# DT accuracy: 0.9242424242424242
# RF accuracy: 0.9242424242424242
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.8787878787878788
#
# metal rock
# DT accuracy: 0.7878787878787878
# RF accuracy: 0.7878787878787878
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.4696969696969697
#
# pop reggae
# DT accuracy: 0.8787878787878788
# RF accuracy: 0.8787878787878788
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6363636363636364
#
# pop rock
# DT accuracy: 0.8787878787878788
# RF accuracy: 0.8787878787878788
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.5303030303030303
#
# reggae rock
# DT accuracy: 0.7727272727272727
# RF accuracy: 0.7727272727272727
# MLP accuracy: 0.48484848484848486
# Grid accuracy: 0.6212121212121212

# %%
df.head()
# Out:
#   label1     label2  DTaccuracy  RFaccuracy  MLPaccuracy  GSaccuracy
# 0  blues  classical    0.833333    0.833333     0.484848    0.575758
# 1  blues    country    0.772727    0.772727     0.484848    0.530303
# 2  blues      disco    0.787879    0.787879     0.484848    0.560606
# 3  blues     hiphop    0.833333    0.833333     0.484848    0.606061
# 4  blues       jazz    0.848485    0.848485     0.500000    0.560606

# %%
df.to_csv('classification_data_2_genre.csv', index=False)
