# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_selection import SelectKBest, f_classif

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
from ipynb.fs.full.data_loading import load_data_from_csv

# %%
data = load_data_from_csv()

# %%
new_data = data.copy()

# %%
df = pd.DataFrame(columns=["label1", "label2", "DTaccuracy", "RFaccuracy", "MLPaccuracy"])

# %%
labels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]
for i in range(len(labels)):
    for j in range(len(labels) - i - 1):
                
        print(labels[i], labels[i + j + 1])
        
        new_data_2genre = new_data[(new_data.label == labels[i]) | (new_data.label == labels[i + j + 1])]

        y = new_data_2genre['label']
        X = new_data_2genre.drop(labels=['label', 'filename', 'audio_data', 'audio_sr'],axis=1)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=0)
        
        param_grid_dt = {'splitter': ['best', 'random'], 'max_depth': ['None', 2, 4, 8],
                         'random_state': [0], 'min_samples_leaf': [1, 2, 4, 8]}
        grid_dt = GridSearchCV(DecisionTreeClassifier(), param_grid_dt, refit = True, verbose = 0, cv = 5)
        grid_dt.fit(X_train, y_train)
        y_pred_dt = grid_dt.predict(X_test)
        dt_accuracy = accuracy_score(y_test, y_pred_dt)
        dt_best_estimator = str(grid_dt.best_estimator_)
        print("DT accuracy:", dt_accuracy)
        print("DT config:", dt_best_estimator)
        
        param_grid_rf = {'n_estimators': [100, 500, 1000], 'max_depth' : [None, 2, 4, 8],
                        'random_state': [0], 'min_samples_leaf': [1, 2, 4, 8]}
        grid_rf = GridSearchCV(RandomForestClassifier(), param_grid_rf, refit = True, verbose = 0, cv = 5)
        grid_rf.fit(X_train, y_train)
        y_pred_rf = grid_rf.predict(X_test)
        rf_accuracy = accuracy_score(y_test, y_pred_rf)
        rf_best_estimator = str(grid_rf.best_estimator_)
        print("RF accuracy:", rf_accuracy)
        print("RF config:", rf_best_estimator)
        
        param_grid_mlp = {'activation': ['identity', 'logistic', 'tanh', 'relu'],
                'solver': ['lbgfs', 'sgd', 'adam'],
                'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,), (250, 500), (250, 500, 250), (1000, 1000)],
                'alpha': [0.0001, 0.05],
                'learning_rate': ['constant', 'invscaling', 'adaptive']}  
        grid_mlp = GridSearchCV(MLPClassifier(), param_grid_mlp, refit = True, verbose = 0, cv=5)
        grid_mlp.fit(X_train, y_train)
        y_pred_mlp = grid_mlp.predict(X_test) 
        mlp_accuracy = accuracy_score(y_test, y_pred_mlp)
        mlp_best_estimator = str(grid_mlp.best_estimator_)
        print("MLP accuracy:", mlp_accuracy)
        print("MLP config:", mlp_best_estimator)
                
        row = {"label1" : labels[i], "label2" : labels[i + j + 1], "DTaccuracy" : dt_accuracy, "RFaccuracy" : rf_accuracy, "MLPaccuracy" : mlp_accuracy,
              "DTestimator": dt_best_estimator, "RFestimator": rf_best_estimator, "MLPestimator": mlp_best_estimator}
        df = df.append(row, ignore_index=True)
        
        print()
# Out:
# blues classical
# DT accuracy: 0.84375
# DT config: DecisionTreeClassifier(max_depth=4, random_state=0, splitter='random')
# RF accuracy: 0.98125
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.76875
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500),
#               learning_rate='invscaling')
#
# blues country
# DT accuracy: 0.675
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0)
# RF accuracy: 0.75
# RF config: RandomForestClassifier(min_samples_leaf=4, n_estimators=500, random_state=0)
# MLP accuracy: 0.575
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(50, 50, 50),
#               learning_rate='adaptive')
#
# blues disco
# DT accuracy: 0.775
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.86875
# RF config: RandomForestClassifier(n_estimators=1000, random_state=0)
# MLP accuracy: 0.625
# MLP config: MLPClassifier(activation='logistic', hidden_layer_sizes=(250, 500))
#
# blues hiphop
# DT accuracy: 0.83125
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0,
#                        splitter='random')
# RF accuracy: 0.90625
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.7
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),
#               learning_rate='invscaling', solver='sgd')
#
# blues jazz
# DT accuracy: 0.66875
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0,
#                        splitter='random')
# RF accuracy: 0.90625
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.58125
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(50, 100, 50))
#
# blues metal
# DT accuracy: 0.89375
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0)
# RF accuracy: 0.88125
# RF config: RandomForestClassifier(n_estimators=1000, random_state=0)
# MLP accuracy: 0.68125
# MLP config: MLPClassifier(activation='logistic', alpha=0.05, hidden_layer_sizes=(250, 500),
#               learning_rate='invscaling')
#
# blues pop
# DT accuracy: 0.85625
# DT config: DecisionTreeClassifier(max_depth=4, random_state=0, splitter='random')
# RF accuracy: 0.9875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.71875
# MLP config: MLPClassifier(activation='tanh', learning_rate='adaptive', solver='sgd')
#
# blues reggae
# DT accuracy: 0.85625
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0)
# RF accuracy: 0.8375
# RF config: RandomForestClassifier(max_depth=2, n_estimators=500, random_state=0)
# MLP accuracy: 0.56875
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(1000, 1000),
#               learning_rate='adaptive', solver='sgd')
#
# blues rock
# DT accuracy: 0.56875
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)
# RF accuracy: 0.75625
# RF config: RandomForestClassifier(min_samples_leaf=4, n_estimators=500, random_state=0)
# MLP accuracy: 0.56875
# MLP config: MLPClassifier(activation='logistic', alpha=0.05, hidden_layer_sizes=(250, 500))
#
# classical country
# DT accuracy: 0.88125
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.93125
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.74375
# MLP config: MLPClassifier(activation='logistic', hidden_layer_sizes=(1000, 1000),
#               solver='sgd')
#
# classical disco
# DT accuracy: 0.95
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0,
#                        splitter='random')
# RF accuracy: 0.98125
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.7625
# MLP config: MLPClassifier(hidden_layer_sizes=(250, 500), learning_rate='adaptive')
#
# classical hiphop
# DT accuracy: 0.91875
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')
# RF accuracy: 0.9625
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.83125
# MLP config: MLPClassifier(activation='logistic', alpha=0.05,
#               hidden_layer_sizes=(250, 500, 250), learning_rate='invscaling')
#
# classical jazz
# DT accuracy: 0.8
# DT config: DecisionTreeClassifier(max_depth=4, random_state=0, splitter='random')
# RF accuracy: 0.80625
# RF config: RandomForestClassifier(n_estimators=500, random_state=0)
# MLP accuracy: 0.71875
# MLP config: MLPClassifier(activation='logistic', alpha=0.05,
#               hidden_layer_sizes=(1000, 1000), learning_rate='adaptive')
#
# classical metal
# DT accuracy: 0.95
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')
# RF accuracy: 0.9875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.79375
# MLP config: MLPClassifier(activation='logistic', hidden_layer_sizes=(1000, 1000),
#               solver='sgd')
#
# classical pop
# DT accuracy: 0.95
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.98125
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.7375
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(50, 100, 50))
#
# classical reggae
# DT accuracy: 0.86875
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0,
#                        splitter='random')
# RF accuracy: 0.98125
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.83125
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),
#               learning_rate='adaptive', solver='sgd')
#
# classical rock
# DT accuracy: 0.8875
# DT config: DecisionTreeClassifier(max_depth=4, min_samples_leaf=2, random_state=0,
#                        splitter='random')
# RF accuracy: 0.9375
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.75
# MLP config: MLPClassifier(activation='logistic', hidden_layer_sizes=(1000, 1000),
#               solver='sgd')
#
# country disco
# DT accuracy: 0.8125
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0)
# RF accuracy: 0.8
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.675
# MLP config: MLPClassifier(activation='logistic', hidden_layer_sizes=(1000, 1000),
#               learning_rate='adaptive', solver='sgd')
#
# country hiphop
# DT accuracy: 0.7375
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')
# RF accuracy: 0.8875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.75
# MLP config: MLPClassifier(activation='logistic', alpha=0.05,
#               hidden_layer_sizes=(1000, 1000), learning_rate='invscaling')
#
# country jazz
# DT accuracy: 0.83125
# DT config: DecisionTreeClassifier(max_depth=4, min_samples_leaf=4, random_state=0,
#                        splitter='random')
# RF accuracy: 0.89375
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.6125
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(1000, 1000),
#               learning_rate='adaptive', solver='sgd')
#
# country metal
# DT accuracy: 0.7875
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)
# RF accuracy: 0.93125
# RF config: RandomForestClassifier(n_estimators=500, random_state=0)
# MLP accuracy: 0.75
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),
#               learning_rate='adaptive')
#
# country pop
# DT accuracy: 0.88125
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.91875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.71875
# MLP config: MLPClassifier(activation='logistic', alpha=0.05, hidden_layer_sizes=(250, 500),
#               learning_rate='adaptive')
#
# country reggae
# DT accuracy: 0.69375
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0)
# RF accuracy: 0.79375
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.51875
# MLP config: MLPClassifier(alpha=0.05, hidden_layer_sizes=(50, 50, 50))
#
# country rock
# DT accuracy: 0.61875
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.75
# RF config: RandomForestClassifier(min_samples_leaf=2, random_state=0)
# MLP accuracy: 0.55625
# MLP config: MLPClassifier(activation='logistic', hidden_layer_sizes=(250, 500, 250),
#               learning_rate='invscaling')
#
# disco hiphop
# DT accuracy: 0.7
# DT config: DecisionTreeClassifier(max_depth=4, min_samples_leaf=4, random_state=0,
#                        splitter='random')
# RF accuracy: 0.8125
# RF config: RandomForestClassifier(min_samples_leaf=2, random_state=0)
# MLP accuracy: 0.45625
# MLP config: MLPClassifier(activation='identity')
#
# disco jazz
# DT accuracy: 0.8
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)
# RF accuracy: 0.9375
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.69375
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(50, 100, 50))
#
# disco metal
# DT accuracy: 0.84375
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)
# RF accuracy: 0.875
# RF config: RandomForestClassifier(n_estimators=500, random_state=0)
# MLP accuracy: 0.63125
# MLP config: MLPClassifier(alpha=0.05)
#
# disco pop
# DT accuracy: 0.83125
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0)
# RF accuracy: 0.80625
# RF config: RandomForestClassifier(n_estimators=500, random_state=0)
# MLP accuracy: 0.6125
# MLP config: MLPClassifier(alpha=0.05, learning_rate='adaptive')
#
# disco reggae
# DT accuracy: 0.76875
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0)
# RF accuracy: 0.78125
# RF config: RandomForestClassifier(min_samples_leaf=8, n_estimators=500, random_state=0)
# MLP accuracy: 0.55
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500, 250),
#               learning_rate='adaptive', solver='sgd')
#
# disco rock
# DT accuracy: 0.60625
# DT config: DecisionTreeClassifier(max_depth=4, min_samples_leaf=2, random_state=0,
#                        splitter='random')
# RF accuracy: 0.74375
# RF config: RandomForestClassifier(max_depth=2, min_samples_leaf=4, n_estimators=1000,
#                        random_state=0)
# MLP accuracy: 0.46875
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500, 250),
#               solver='sgd')
#
# hiphop jazz
# DT accuracy: 0.91875
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.9375
# RF config: RandomForestClassifier(n_estimators=500, random_state=0)
# MLP accuracy: 0.8125
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500),
#               learning_rate='invscaling')
#
# hiphop metal
# DT accuracy: 0.775
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)
# RF accuracy: 0.8875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.61875
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),
#               solver='sgd')
#
# hiphop pop
# DT accuracy: 0.76875
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')
# RF accuracy: 0.8375
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.44375
# MLP config: MLPClassifier(activation='logistic', hidden_layer_sizes=(1000, 1000),
#               solver='sgd')
#
# hiphop reggae
# DT accuracy: 0.6625
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.69375
# RF config: RandomForestClassifier(n_estimators=1000, random_state=0)
# MLP accuracy: 0.6375
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250))
#
# hiphop rock
# DT accuracy: 0.7625
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)
# RF accuracy: 0.84375
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.63125
# MLP config: MLPClassifier(activation='logistic', alpha=0.05,
#               hidden_layer_sizes=(1000, 1000), learning_rate='adaptive')
#
# jazz metal
# DT accuracy: 0.89375
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')
# RF accuracy: 0.9875
# RF config: RandomForestClassifier(n_estimators=1000, random_state=0)
# MLP accuracy: 0.8375
# MLP config: MLPClassifier(activation='tanh', learning_rate='adaptive', solver='sgd')
#
# jazz pop
# DT accuracy: 0.90625
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')
# RF accuracy: 0.95
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.7875
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500),
#               learning_rate='adaptive')
#
# jazz reggae
# DT accuracy: 0.8375
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0,
#                        splitter='random')
# RF accuracy: 0.85
# RF config: RandomForestClassifier(min_samples_leaf=8, n_estimators=500, random_state=0)
# MLP accuracy: 0.78125
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500), solver='sgd')
#
# jazz rock
# DT accuracy: 0.7375
# DT config: DecisionTreeClassifier(max_depth=4, min_samples_leaf=2, random_state=0,
#                        splitter='random')
# RF accuracy: 0.84375
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.5
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(50, 50, 50))
#
# metal pop
# DT accuracy: 0.875
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.9875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.53125
# MLP config: MLPClassifier(activation='identity', learning_rate='invscaling')
#
# metal reggae
# DT accuracy: 0.825
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0,
#                        splitter='random')
# RF accuracy: 0.91875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.73125
# MLP config: MLPClassifier(activation='tanh', hidden_layer_sizes=(1000, 1000), solver='sgd')
#
# metal rock
# DT accuracy: 0.70625
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')
# RF accuracy: 0.8875
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.5875
# MLP config: MLPClassifier(alpha=0.05, hidden_layer_sizes=(50, 100, 50))
#
# pop reggae
# DT accuracy: 0.76875
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0)
# RF accuracy: 0.825
# RF config: RandomForestClassifier(min_samples_leaf=2, n_estimators=1000, random_state=0)
# MLP accuracy: 0.53125
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500, 250),
#               solver='sgd')
#
# pop rock
# DT accuracy: 0.8125
# DT config: DecisionTreeClassifier(max_depth=2, random_state=0)
# RF accuracy: 0.9
# RF config: RandomForestClassifier(random_state=0)
# MLP accuracy: 0.625
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500),
#               learning_rate='invscaling', solver='sgd')
#
# reggae rock
# DT accuracy: 0.725
# DT config: DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)
# RF accuracy: 0.86875
# RF config: RandomForestClassifier(n_estimators=1000, random_state=0)
# MLP accuracy: 0.5
# MLP config: MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(50, 50, 50),
#               learning_rate='invscaling')

# %%
df.head()
# Out:
#   label1     label2  DTaccuracy  RFaccuracy  MLPaccuracy  \
# 0  blues  classical     0.84375     0.98125      0.76875
# 1  blues    country     0.67500     0.75000      0.57500
# 2  blues      disco     0.77500     0.86875      0.62500
# 3  blues     hiphop     0.83125     0.90625      0.70000
# 4  blues       jazz     0.66875     0.90625      0.58125
#
#                                          DTestimator  \
# 0  DecisionTreeClassifier(max_depth=4, random_sta...
# 1  DecisionTreeClassifier(max_depth=2, min_sample...
# 2  DecisionTreeClassifier(max_depth=2, random_sta...
# 3  DecisionTreeClassifier(max_depth=2, min_sample...
# 4  DecisionTreeClassifier(max_depth=2, min_sample...
#
#                                          RFestimator  \
# 0             RandomForestClassifier(random_state=0)
# 1  RandomForestClassifier(min_samples_leaf=4, n_e...
# 2  RandomForestClassifier(n_estimators=1000, rand...
# 3             RandomForestClassifier(random_state=0)
# 4             RandomForestClassifier(random_state=0)
#
#                                         MLPestimator
# 0  MLPClassifier(activation='tanh', hidden_layer_...
# 1  MLPClassifier(activation='tanh', hidden_layer_...
# 2  MLPClassifier(activation='logistic', hidden_la...
# 3  MLPClassifier(activation='tanh', hidden_layer_...
# 4  MLPClassifier(activation='tanh', alpha=0.05, h...

# %%
df.to_csv('classification_data_2_genre.csv', index=False)

# %%
df.mean()['DTaccuracy']
# Out:
# 0.8013888888888889

# %%
df.mean()['RFaccuracy']
# Out:
# 0.8798611111111111

# %%
df.mean()['MLPaccuracy']
# Out:
# 0.6556944444444444

# %%
df.groupby(['DTestimator']).mean()['DTaccuracy']
# Out:
# DTestimator
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0)                                               0.839583
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=2, random_state=0,\n                       splitter='random')    0.885417
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0)                                               0.751786
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=4, random_state=0,\n                       splitter='random')    0.825000
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0)                                               0.756250
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=8, random_state=0,\n                       splitter='random')    0.750000
# DecisionTreeClassifier(max_depth=2, random_state=0)                                                                   0.819444
# DecisionTreeClassifier(max_depth=2, random_state=0, splitter='random')                                                0.840179
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=2, random_state=0,\n                       splitter='random')    0.743750
# DecisionTreeClassifier(max_depth=4, min_samples_leaf=4, random_state=0,\n                       splitter='random')    0.765625
# DecisionTreeClassifier(max_depth=4, random_state=0, splitter='random')                                                0.833333
# Name: DTaccuracy, dtype: float64

# %%
df.groupby(['RFestimator']).mean()['RFaccuracy']
# Out:
# RFestimator
# RandomForestClassifier(max_depth=2, min_samples_leaf=4, n_estimators=1000,\n                       random_state=0)    0.743750
# RandomForestClassifier(max_depth=2, n_estimators=500, random_state=0)                                                 0.837500
# RandomForestClassifier(min_samples_leaf=2, n_estimators=1000, random_state=0)                                         0.825000
# RandomForestClassifier(min_samples_leaf=2, random_state=0)                                                            0.781250
# RandomForestClassifier(min_samples_leaf=4, n_estimators=500, random_state=0)                                          0.753125
# RandomForestClassifier(min_samples_leaf=8, n_estimators=500, random_state=0)                                          0.815625
# RandomForestClassifier(n_estimators=1000, random_state=0)                                                             0.860000
# RandomForestClassifier(n_estimators=500, random_state=0)                                                              0.871250
# RandomForestClassifier(random_state=0)                                                                                0.916587
# Name: RFaccuracy, dtype: float64

# %%
df.groupby(['MLPestimator']).mean()['MLPaccuracy']
# Out:
# MLPestimator
# MLPClassifier(activation='identity')                                                                                                       0.456250
# MLPClassifier(activation='identity', learning_rate='invscaling')                                                                           0.531250
# MLPClassifier(activation='logistic', alpha=0.05,\n              hidden_layer_sizes=(1000, 1000), learning_rate='adaptive')                 0.675000
# MLPClassifier(activation='logistic', alpha=0.05,\n              hidden_layer_sizes=(1000, 1000), learning_rate='invscaling')               0.750000
# MLPClassifier(activation='logistic', alpha=0.05,\n              hidden_layer_sizes=(250, 500, 250), learning_rate='invscaling')            0.831250
# MLPClassifier(activation='logistic', alpha=0.05, hidden_layer_sizes=(250, 500))                                                            0.568750
# MLPClassifier(activation='logistic', alpha=0.05, hidden_layer_sizes=(250, 500),\n              learning_rate='adaptive')                   0.718750
# MLPClassifier(activation='logistic', alpha=0.05, hidden_layer_sizes=(250, 500),\n              learning_rate='invscaling')                 0.681250
# MLPClassifier(activation='logistic', hidden_layer_sizes=(1000, 1000),\n              learning_rate='adaptive', solver='sgd')               0.675000
# MLPClassifier(activation='logistic', hidden_layer_sizes=(1000, 1000),\n              solver='sgd')                                         0.682813
# MLPClassifier(activation='logistic', hidden_layer_sizes=(250, 500))                                                                        0.625000
# MLPClassifier(activation='logistic', hidden_layer_sizes=(250, 500, 250),\n              learning_rate='invscaling')                        0.556250
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(1000, 1000),\n              learning_rate='adaptive', solver='sgd')       0.590625
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500),\n              learning_rate='invscaling')                     0.812500
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500),\n              learning_rate='invscaling', solver='sgd')       0.625000
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500, 250),\n              learning_rate='adaptive', solver='sgd')    0.550000
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(250, 500, 250),\n              solver='sgd')                              0.500000
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(50, 100, 50))                                                             0.659375
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(50, 50, 50),\n              learning_rate='invscaling')                   0.500000
# MLPClassifier(activation='tanh', hidden_layer_sizes=(1000, 1000), solver='sgd')                                                            0.731250
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500),\n              learning_rate='adaptive')                                   0.787500
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500),\n              learning_rate='invscaling')                                 0.768750
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500), solver='sgd')                                                              0.781250
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250))                                                                       0.637500
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),\n              learning_rate='adaptive')                              0.750000
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),\n              learning_rate='adaptive', solver='sgd')                0.831250
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),\n              learning_rate='invscaling', solver='sgd')              0.700000
# MLPClassifier(activation='tanh', hidden_layer_sizes=(250, 500, 250),\n              solver='sgd')                                          0.618750
# MLPClassifier(activation='tanh', hidden_layer_sizes=(50, 100, 50))                                                                         0.693750
# MLPClassifier(activation='tanh', hidden_layer_sizes=(50, 50, 50))                                                                          0.500000
# MLPClassifier(activation='tanh', hidden_layer_sizes=(50, 50, 50),\n              learning_rate='adaptive')                                 0.575000
# MLPClassifier(activation='tanh', learning_rate='adaptive', solver='sgd')                                                                   0.778125
# MLPClassifier(alpha=0.05)                                                                                                                  0.631250
# MLPClassifier(alpha=0.05, hidden_layer_sizes=(50, 100, 50))                                                                                0.587500
# MLPClassifier(alpha=0.05, hidden_layer_sizes=(50, 50, 50))                                                                                 0.518750
# MLPClassifier(alpha=0.05, learning_rate='adaptive')                                                                                        0.612500
# MLPClassifier(hidden_layer_sizes=(250, 500), learning_rate='adaptive')                                                                     0.762500
# Name: MLPaccuracy, dtype: float64
